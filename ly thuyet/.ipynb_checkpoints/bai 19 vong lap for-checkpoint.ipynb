# %%
for i in range(1,21):
    print(i, end = ' ')
    if i%7==0:
        break
    print('cau lenh duoi break')
# Out:
# 1 cau lenh duoi break
# 2 cau lenh duoi break
# 3 cau lenh duoi break
# 4 cau lenh duoi break
# 5 cau lenh duoi break
# 6 cau lenh duoi break
# 7
