# %%
# ord() : chuyển ký tự sang mã ASCII
# chr() : chuyển mã ASCII sang ký tự
if __name__ == "__main__":
    s = '28tech'
    for i in range(len(s)):
        print(s[i], end = ' ')
    print()
    for x in s:
        print(x, end = ' ')
# Out:
# 2 8 t e c h
# 2 8 t e c h
