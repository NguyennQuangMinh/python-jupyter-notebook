# %%
from math import *

if __name__ == "__main__":
    n = int(input())
    a = list(map(int, input().split()))
    a.sort()
    dem = 1
    for i in range(1, len(a)):
        if a[i] != a[i-1]:
            dem += 1
    print(dem)
    print(len(a))
# Out:
#  10
#  2 2 2 3 4 5 1
# 5
# 7
