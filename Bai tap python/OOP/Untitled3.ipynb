# %%
class nhanvien:
    def __init__(self, ma, ten, gioitinh, ns, diachi, mathue, hopdong):
        self.ma = ma
        self.ten = ten
        self.gioitinh = gioitinh
        self.ns = ns
        self.diachi = diachi
        self.mathue = mathue
        self.hopdong = hopdong
    def __str__(self):
        return f'{self.ma} {}'

if __name__ == "__main__":
