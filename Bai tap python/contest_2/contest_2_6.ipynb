# %%
n = int(input())
#1 n co phai la so chan hay ko
if n%2==0:
    print('Yes')
else: print('No')
#2 n co phai la so vua chia het cho 3 vua chia het cho 5 hay ko
if n%3 == 0 and n%5 ==0:
    print('Yes')
else: print('No')
#3 n la so chia het cho 3 nhung ko chia het cho 7
if n%3==0 and n%7!=0:
    print('Yes')
else: print('No')
#4 n chia het cho 3 hoac 7 
if n%3==0 or n%7 ==0:
    print('Yes')
else: print('No')
#5 n la so lon hon 30 va nho hon 50
if n>30 and n< 50:
    print('Yes')
else: print('No')
#6 
if n>=30 and (n%2==0 or n%3==0 or n%5==0):
    print('Yes')
else:print('No')
#7 n co phai la so co 2 chu so, chu so tan cung la so nguyen to
r = n%10
if n>=10 and n<=99 and (r==2 or r==3 or r==5 or r==7):
    print('Yes')
else: print('No')
#8 n co phai la so khong vuot qua 100 va chia het cho 23
if n<=100 and n%23==0:
    print('Yes')
else: print('No')
#9: 
if n<10 or n>20:
    print('Yes')
else: print('No')
#10 n co chu so tan cung la boi cua 3
if r%3==0:
    print('Yes')
else: print('No')
# Out:
#  263
# No
# No
# No
# No
# No
# No
# No
# No
# Yes
# Yes
