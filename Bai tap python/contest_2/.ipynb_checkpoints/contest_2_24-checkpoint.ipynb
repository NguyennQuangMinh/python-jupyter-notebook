# %%
# d1: tu nhà đến cua hang 1
# d2: tu nha den cua hang 2
# d3: tu cua hang 1 den cua hang 2
d1, d2, d3 = map(int, input().split())
TH1 = d1+d2+d3
TH2 = 2*d1+2*d2
TH3 = 2*d1+2*d3
TH4 = 2*d2+2*d3
print(min(TH1, TH2, TH3, TH4))
# Out:
#  832 56 273
# 658
