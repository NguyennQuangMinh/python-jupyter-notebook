# %%
a,b,c,d = map(int, input().split())
tmp = a
#tim so nho nhat
if tmp>b:
    tmp=b
if tmp>c:
    tmp=c
if tmp>d:
    tmp=d

#tim so lon nhat
tmp2=a
if tmp2<b:
    tmp2=b
if tmp2<c:
    tmp2=c
if tmp2<d:
    tmp2=d
print(tmp, tmp2)
# Out:
#  546 272 839 508
# 272 839
