# %%
n = int(input())
tmp1= n//100 #tinh ra so to toi thieu khi doi sang 100 đô
tmp2=(n%100)//20 #lay phan du chia tiep cho 20 de lay ra phan can doi sang 20 đô
tmp3=(n%100)%20//10
tmp4=(n%100)%20%10//5
tmp5=(n%100)%20%10%5
print(tmp1+tmp2+tmp3+tmp4+tmp5)
# Out:
#  3455
# 38
