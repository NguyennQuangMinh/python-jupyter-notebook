# %%
a1, a2 ,a3 ,a4 ,a5 = map(int, input().split())
tong = a1+a2+a3+a4+a5
if tong%5==0:
    b = tong//5
    if b!=0:
        print(b)
    else:
        print(-1)
else:
    print(-1)
# Out:
#  2 5 4 0 4
# 3
