# %%
# de quy bai 6: doi he thap phan sang he nhi phan
def F(n):
    if n!=0:
        F(n//2)
        print(n%2, end ='')

if __name__ == '__main__':
    n = int(input())
    if n == 0:
        print(0)
    else:
        F(n)
# Out:
#  18
# 10010
