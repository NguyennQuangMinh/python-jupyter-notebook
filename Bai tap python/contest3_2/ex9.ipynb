# %%
from math import *

def tn(n):
    rev = 0
    tmp = n
    while n!=0:
        rev = rev*10 + n%10
        n//=10
    return rev == tmp

def check(n):
    last = n%10
    tmp = 0
    n//=10
    while n>=10:
        tmp = tmp * 10 + n%10
        n//=10
    return ((last * 2 == n) or (n*2 == last)) and tn(tmp)

# tim ucln cua 2 so
def _gcd(a, b):
    while b!=0:
        a, b = b, a%b
    return a
if __name__ == '__main__':
    a, b = map(int, input().split())
    print(_gcd(a,b), a*b // _gcd(a,b))
# Out:
#  20 50
# 10 100
