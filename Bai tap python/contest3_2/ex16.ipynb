# %%
from math import *

if __name__ == '__main__':
    a, b = map(int, input().split())
    for i in range(a, b):
        for j in range(i+1, b+1):
            if gcd(i, j) == 1:
                print("(", i,",", j, ")", sep = '')
# Out:
#  5 10
# (5,6)
# (5,7)
# (5,8)
# (5,9)
# (6,7)
# (7,8)
# (7,9)
# (7,10)
# (8,9)
# (9,10)
