# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    cnt = [0] * 10000001
    for x in a:
        cnt[x] += 1
    l, r = min(a), max(a)
    for i in range(l, r+1):
        if cnt[i] != 0:
            print(i, cnt[i])
            cnt[i] = 0
# Out:
#  5
#  1 5 2 5 1
# 1 2
# 2 1
# 5 2
