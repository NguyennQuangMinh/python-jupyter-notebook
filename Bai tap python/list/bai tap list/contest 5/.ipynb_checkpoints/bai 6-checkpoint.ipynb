# %%
from math import *

if __name__ == '__main__':
    K = int(input())
    n = int(input())
    a = list(map(int, input().split()))
    dem = 0
    for i in range(n):
        for j in range(i+1, n):
            if a[i]+a[j] == K:
                dem+=1
    print(dem)
# Out:
#  3
#  5
#  1 2 2 1 4
# 4
