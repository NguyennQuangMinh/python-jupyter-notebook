# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    min_kc = 10**18
    for i in range(n):
        for j in range(i+1, n):
            if abs(a[j] - a[i]) < min_kc:
                min_kc = (a[j] - a[i])
    print(min_kc)
# Out:
#  5
#  1 3 9 8 4
# 1
