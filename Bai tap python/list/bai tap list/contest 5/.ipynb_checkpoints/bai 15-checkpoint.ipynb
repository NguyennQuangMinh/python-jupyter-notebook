# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    max2, max1 = -10**18, -10**18
    for x in a:
        if x > max1:
            max2 = max1
            max1 = x
        elif x > max2:
            max2 = x
    print(max1, max2)
# Out:
#  5
#  1 4 2 3 9
# 9 4
