# %%
from math import *

if __name__ == "__main__":
    n = int(input())
    a = list(map(int, input().split()))
    b = a[:]
    a.reverse()
    if a == b:
        print('Yes')
    else:
        print('No')
# Out:
#  5
#  1 2 4 5 5
# No
