# %%
# cho 1 số nguyên X, đếm xem trong mảng có bao nhiêu số lớn hơn X, và bao nhiêu số nhỏ hơn X
from math import *

if __name__ == '__main__':
    X = int(input())
    n = int(input())
    a = list(map(int, input().split()))
    dem_l, dem_b = 0, 0
    for item in a:
        if item > X:
            dem_l += 1
        if item < X:
            dem_b += 1
    print(dem_l, dem_b, sep = ' ')
# Out:
#  5
#  7
#  4 5 6 2 1 9 3
# 2 4
