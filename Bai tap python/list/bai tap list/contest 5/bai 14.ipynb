# %%
from math import *

def _gcd(a, b):
    while b!=0:
        a, b = b, a%b
    return a

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    res = 0
    for i in range(n):
        res = _gcd(res, a[i])
    print(res)
# Out:
#  5
#  1 2 3 4 5
# 1
