# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    cnt = [0] * 1000001
    for x in a:
        cnt[x] += 1
    for x in a:
        if cnt[x] != 0:
            print(x, cnt[x])
            cnt[x] = 0
# Out:
#  5
#  1 19 1 9 19
# 1 2
# 19 2
# 9 1
