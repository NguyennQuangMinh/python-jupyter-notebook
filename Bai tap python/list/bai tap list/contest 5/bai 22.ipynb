# %%
if __name__ == '__main__':
    n, x = map(int, input().split())
    a = list(map(int, input().split()))
    if x in a:
        a.pop(a.index(x))
        for item in a:
            print(item, end = ' ')
    else:
        print('not fould')
# Out:
#  5 2
#  1 3 2 5 2
# 1 3 5 2
