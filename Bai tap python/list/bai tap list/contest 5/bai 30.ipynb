# %%
from math import *
# nếu cùng tần suất in ra số xuất hiện trước
if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    cnt = [0] * 1000001
    max_pre, res = 0, 0
    for x in a:
        cnt[x] += 1
    for x in a:
        if max_pre < cnt[x]:
            max_pre = cnt[x]
            res = x
    print(res, max_pre)
# Out:
#  5
#  7 0 1 4 2
# 7 1
