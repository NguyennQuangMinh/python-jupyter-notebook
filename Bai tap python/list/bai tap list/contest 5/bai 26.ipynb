# %%
from math import *
# đếm xem có bao nhiêu giá trị khác nhau trong mảng
if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    dem = 0
    cnt = [0] * 1000
    for x in a:
        cnt[x] += 1
    for x in a:
        if cnt[x] != 0:
            dem += 1
            cnt[x] = 0
    print(dem)
# Out:
#  5
#  1 5 2 7 1
# 4
