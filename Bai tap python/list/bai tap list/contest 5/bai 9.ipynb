# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    cnt = [0] * 10000001
    for x in a:
        cnt[x] += 1
    for x in a:
        if cnt[x] != 0:
            print(x, cnt[x], sep = ' ')
            cnt[x] = 0
# Out:
#  5
#  1 2 1 1 2
# 1 3
# 2 2
