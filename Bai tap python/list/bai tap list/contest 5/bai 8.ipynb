# %%
from math import *

if __name__ == '__main__':
    n = int(input())
    a = list(map(int, input().split()))
    cnt = [0] * 1001
    for x in a:
        if cnt[x] == 0:
            print(x, end = ' ')
            cnt[x] = 1
# Out:
#  5
#  1 2 12 2 1
# 1 2 12
