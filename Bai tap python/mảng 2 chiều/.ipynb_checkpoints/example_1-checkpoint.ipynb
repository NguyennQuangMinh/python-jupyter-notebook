# %%
if __name__ == "__main__":
    n, m = map(int, input().split())
    a = []
    for i in range(n):
        b = list(map(int, input().split()))
        a.append(b)
    for x in range(n):
        print(sum(a[x]))  # Đây là hàm sum chuẩn của Python
# Out:
#  2 3
#  1 2 3
#  4 5 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       6     a.append(b)
#       7 for x in range(n):
# ----> 8     print(sum(a[x]))
#
# TypeError: 'int' object is not callable
