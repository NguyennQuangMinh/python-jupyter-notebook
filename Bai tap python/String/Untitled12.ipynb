# %%
if __name__ == "__main__":
    n = int(input())
    for _ in range(n):
        s = input().lower()
        a = s.split()
        ns = a[-1]
        print(a[-2], end = '')
        for i in range(0, len(a)-2):
            print(a[i][0],end = '')
        print("@xyz.edu.vn")
        b = ns.split('/')
        for x in b:
            print(int(x), end = '')
        print()
# Out:
#  2
#  Nguyen Quang Minh 19/05/2002
# minhnq@xyz.edu.vn
# 1952002
#  Nguyen Van B 01/02/2003
# bnv@xyz.edu.vn
# 122003
