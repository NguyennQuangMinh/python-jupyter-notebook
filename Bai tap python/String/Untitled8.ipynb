# %%
# kiểm tra xem chuỗi nhập vào có phải là chuỗi chỉ có chữ in hoa hoặc in thường hay không

if __name__ == "__main__":
    s1 = input()
    as = 0
    for i in s1:   
        if i != s1.islower() or s1.isupper:
            return as
    as = 1
