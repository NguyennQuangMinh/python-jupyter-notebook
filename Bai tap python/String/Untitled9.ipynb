# %%
if __name__ == "__main__":
    s = input()
    a = s.split()
    a.sort()
    print(' '.join(a))
    a.sort(key = lambda x : (len(x), x))
    print(' '.join(a))
# Out:
#  hoc lap trinh php
# hoc lap php trinh
# hoc lap php trinh
