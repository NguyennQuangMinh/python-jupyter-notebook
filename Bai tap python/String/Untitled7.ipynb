# %%
# lật ngược và kiểm tra xem có giống xâu ký tự đầu tiên hay không
if __name__ == "__main__":
    s1 = input()
    s2 = s1[::-1] # lật ngược chuỗi s1
    if s2==s1:
        print('yes')
    else:
        print('No')
# Out:
#  asdsa
# yes
