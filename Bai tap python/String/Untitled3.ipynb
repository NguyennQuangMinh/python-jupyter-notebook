# %%
if __name__ == '__main__':
    n = input()
    d = dict({})
    for i in n:
        if i in d:
            d[i] += 1
        else:
            d[i] = 1
    for x,y in d.items():
        print(x, y)
    print()
    for kytu in sorted(d):
        print(kytu, d[kytu])
# Out:
#  1243rewfret4qwews
# 1 1
# 2 1
# 4 2
# 3 1
# r 2
# e 3
# w 3
# f 1
# t 1
# q 1
# s 1
#
# 1 1
# 2 1
# 3 1
# 4 2
# e 3
# f 1
# q 1
# r 2
# s 1
# t 1
# w 3
