# %%
# dạng 2: đếm tần suất, tách chuỗi theo ký tự

if __name__ == "__main__":
    a = '28tech.python!28tech?java.java python'
    delim = '.?!'
    for x in delim:
        a = a.replace(x, ' ')
    print(a.split())
# Out:
# ['28tech', 'python', '28tech', 'java', 'java', 'python']
